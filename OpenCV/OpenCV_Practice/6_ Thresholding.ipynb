# %% [markdown]
# # 스레시홀딩 (Thresholding)
#
#
# + Binary Image를 만드는 가장 대표적인 방법
#     * Binary Image = 검은색/흰색만으로 표현한 이미지를 의미
#
#
# + Thresholding은 여러 값을 어떤 임계점을 기준으로 2가지 부류로 나누는 방법을 의미한다.
#
#
# ## 전역 스레시홀딩
#
# - 어떤 임계값을 정한 뒤에, 픽셀값이 임계값을 넘으면 255, 넘지 않으면 0으로 지정하는 방식

# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

img = cv2.imread('./Ryan/5.jpg', cv2.IMREAD_GRAYSCALE)
thresh_np = np.zeros_like(img)
thresh_np[ img > 127 ] = 255

ret, thresh_cv = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
print(ret)

imgs = {'Original ' : img, 'Numpy API ' : thresh_np, 'cv2.threshold ' : thresh_cv}
for i, (key, value) in enumerate(imgs.items()):
    plt.subplot(1, 3, i+1)
    plt.title(key)
    plt.imshow(value, cmap = 'gray')
    plt.xticks([]); plt.yticks([])

plt.show()
# Out:
# 127.0

# %% [markdown]
# # ret, out = cv2.threshold(img, threshold, value, type_flag)
# img: 변환할 이미지
#
#
# threshold: 스레시홀딩 임계값
#
#
# value: 임계값 기준에 만족하는 픽셀에 적용할 값
#
#
# type_flag: 스레시홀딩 적용 방법
#
# ##### type_flag 값
#
# cv2.THRESH_BINARY: 픽셀 값이 임계값을 넘으면 value로 지정하고, 넘지 못하면 0으로 지정
#
#
# cv2.THRESH_BINARY_INV: cv.THRESH_BINARY의 반대
#
#
# cv2.THRESH_TRUNC: 픽셀 값이 임계값을 넘으면 value로 지정하고, 넘지 못하면 원래 값 유지
#
#
# cv2.THRESH_TOZERO: 픽셀 값이 임계값을 넘으면 원래 값 유지, 넘지 못하면 0으로 지정
#
#
# cv2.THRESH_TOZERO_INV: cv2.THRESH_TOZERO의 반대
