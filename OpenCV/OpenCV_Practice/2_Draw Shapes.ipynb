# %%
import cv2

# %%
img = cv2.imread('White_board.jpg')

# %% [markdown]
# ### cv2.line(img, startingpoint, endpoint, color, thickness, lineType)
# - 선을 그리는 함수
# - img : 그림을 그릴 이미지 파일
# - startingpoint = 선 시작 좌표 (ex) (0, 0)
# - endingpoint = 선 종료 좌표 (ex) (100, 0)
# - color : BGR형태 (주의 - RGB가 아님) (ex) (255, 0, 0) = Blue
# - thickness = int Type, 선의 두께, default = 1
# - lineType = 선 그리기 형식

# %%
cv2.line(img, (50, 50), (150, 50), (255, 0, 0))
cv2.line(img, (200, 50), (300, 50), (0,255,0))
cv2.line(img, (350, 50), (450, 50), (0,0,255))

# 하늘색(파랑+초록) 10픽셀 선      
cv2.line(img, (100, 100), (400, 100), (255,255,0), 10)          
# 분홍(파랑+빨강) 10픽셀 선      
cv2.line(img, (100, 150), (400, 150), (255,0,255), 10)          
# 노랑(초록+빨강) 10픽셀 선      
cv2.line(img, (100, 200), (400, 200), (0,255,255), 10)          
# 회색(파랑+초록+빨강) 10픽셀 선  
cv2.line(img, (100, 250), (400, 250), (200,200,200), 10)        
# 검정 10픽셀 선    
cv2.line(img, (100, 300), (400, 300), (0,0,0), 10)                    

# 4연결 선
cv2.line(img, (100, 350), (400, 400), (0,0,255), 20, cv2.LINE_4)   
# 8연결 선
cv2.line(img, (100, 400), (400, 450), (0,0,255), 20, cv2.LINE_8)    
# 안티에일리어싱 선 
cv2.line(img, (100, 450), (400, 500), (0,0,255), 20, cv2.LINE_AA)   
# 이미지 전체에 대각선 
cv2.line(img, (0,0), (500,500), (0,0,255))                      

cv2.imshow('lines', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imwrite('Draw1.jpg', img)
# Out:
# True

# %% [markdown]
# ![Draw1.jpg](attachment:Draw1.jpg)

# %% [markdown]
# ## cv2.rectangle(img, start, end, color, thickness, lineType)
# - 사각형을 그리는 함수
# - start : 시작 좌표
# - end : 끝 좌표
# - color : BGR Type 색상
# - thickness : int Type 선의 두께, default = 1
# - lineType : 선 그리기 형식

# %%
img = cv2.imread('White_board.jpg')

cv2.rectangle(img, (50, 50), (150, 150), (255, 0, 0))
cv2.rectangle(img, (300, 300), (100, 100), (0, 255, 0), 10)
cv2.rectangle(img, (450, 200), (200, 450), (0, 0, 255), -1)

cv2.imshow('rectangle', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imwrite('Draw2.jpg', img)
# Out:
# True

# %% [markdown]
# ![Draw2.jpg](attachment:Draw2.jpg)

# %% [markdown]
# ## cv2.polylines(img, pts, isClosed, color, thickness, lineType)
# - img : 그림을 그릴 이미지 파일
# - pts :  연결학 점 좌표, Numpy array Type
# - isClosed : 도형의 닫힘 여부
# - color : BGR Type 색상
# - thickness : int Type 선의 두께
# - lineType : 선 그리기 형식

# %%
import numpy as np

img = cv2.imread('White_board.jpg')

pts1 = np.array( [[50, 50], [150, 150], [100, 140], [200, 240]] , dtype = np.int32 )
pts2 = np.array( [[350, 50], [250, 200], [450, 200]], dtype = np.int32 )
pts3 = np.array( [[150, 300], [50, 450], [250, 450]], dtype = np.int32 )
pts4 = np.array( [[350, 250], [450, 350], [400, 450], [300, 450], [250, 350]], dtype = np.int32 )

cv2.polylines(img, [pts1], False, (255, 0, 0))
cv2.polylines(img, [pts1], True, (255, 0, 0))

cv2.polylines(img, [pts2], False, (0, 0, 0), 10)

cv2.polylines(img, [pts3], True, (0, 0, 255), 10)
cv2.polylines(img, [pts3], False, (0, 0, 255), 10)

cv2.polylines(img, [pts4], True, (0, 0, 0))

cv2.imshow('polylines', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imwrite('Draw_polylines.jpg', img)
# Out:
# True

# %% [markdown]
# ## 원 그리기
# ### cv2.circle(img, center, radius, color, thickness, lineType)
# - center = 원의 중심 좌표(x,y)
# - radius = 원의 반지름 길기
# - 그 외 위와 동일한 구조
#
# ## 타원 그리기
# ### cv2.ellipse(img, center, axis, angle, startAngle, endAngle, color, thickness, lineType)
# - center = 타원의 중심좌표(x,y)
# - axis = 타원의 장축의 길이, 단축의 길이
# - angle = 타원의 중심을 기준으로, 축 회전 각도
# - startAngle = 타원의 호가 시작하는 각도
# - endAngle = 타원의 호가 끝나는 각도

# %%
img = cv2.imread('White_board.jpg')

cv2.circle(img, (150, 150), 100, (255, 0, 0))
cv2.circle(img, (250, 250), 50, (120, 120, 0), 5)
cv2.circle(img, (400, 150), 100, (0, 0, 255), -1)

cv2.ellipse(img, (50, 300), (50, 50), 0, 0, 360, (0, 0, 255))

# 아래 반원 ( 0 ~ 180 )
cv2.ellipse(img, (150, 300), (50, 50), 0, 0, 180, (255,0,0))    
# 윗 반원 ( 181 ~ 360 )
cv2.ellipse(img, (200, 300), (50, 50), 0, 181, 360, (0,0,255))    

# 납작한 타원
cv2.ellipse(img, (325, 300), (75, 50), 0, 0, 360, (0,255,0))    
# 원홀쭉한 타원
cv2.ellipse(img, (450, 300), (50, 75), 0, 0, 360, (255,0,255))

cv2.imshow('circles', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imwrite('Draw_circles.jpg', img)
# Out:
# True

# %% [markdown]
# ![Draw_circles.jpg](attachment:Draw_circles.jpg)

# %% [markdown]
# ## 글 쓰기
# ### cv2.putText(img, text, org, font, fontScale, color, thickness, lineType)

# %%
img = cv2.imread('White_board.jpg')

cv2.putText(img, "Plain", (50, 30), cv2.FONT_HERSHEY_PLAIN, 1, (0, 0,0))            
cv2.putText(img, "Simplex", (50, 70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0,0))        
cv2.putText(img, "Duplex", (50, 110), cv2.FONT_HERSHEY_DUPLEX, 1, (0, 0,0))         
cv2.putText(img, "Simplex", (200, 110), cv2.FONT_HERSHEY_SIMPLEX, 2, (0,0,250)) 

cv2.putText(img, "Complex Small", (50, 180), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0,0))   
cv2.putText(img, "Complex", (50, 220), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0,0))
cv2.putText(img, "Triplex", (50, 260), cv2.FONT_HERSHEY_TRIPLEX, 1, (0, 0,0))               
cv2.putText(img, "Complex", (200, 260), cv2.FONT_HERSHEY_TRIPLEX, 2, (0,0,255))               

cv2.putText(img, "Script Simplex", (50, 330), cv2.FONT_HERSHEY_SCRIPT_SIMPLEX, 1, (0, 0, 0)) 
cv2.putText(img, "Script Complex", (50, 370), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 1, (0, 0,0)) 
cv2.putText(img, "Plain Italic", (50, 430),   cv2.FONT_HERSHEY_PLAIN | cv2.FONT_ITALIC, 1, (0, 0,0)) 
cv2.putText(img, "Complex Italic", (50, 470), cv2.FONT_HERSHEY_COMPLEX | cv2.FONT_ITALIC, 1, (0, 0,0)) 

cv2.imshow('draw text', img)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite('Draw_text.jpg', img)
# Out:
# True

# %% [markdown]
# ![Draw_text.jpg](attachment:Draw_text.jpg)
